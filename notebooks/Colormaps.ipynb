# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 10, 10)

# %%
plt.plot(x, x*x, '.-')

# %%
x, y = np.meshgrid(np.r_[:100], np.r_[:200])

# %%
plt.subplot(1, 2, 1)
plt.imshow(x)
plt.subplot(1, 2, 2)
plt.imshow(y)

# %%
x, y = np.meshgrid(np.r_[-1:1:0.01], np.r_[-1:1:0.01])

fig, ax = plt.subplots(1, 3, figsize=(10, 4))
ax[0].imshow(x)
ax[1].imshow(y)
ax[2].imshow(x*x+y*y)

# %%
x, y = np.meshgrid(np.r_[-1:1:0.01], np.r_[-1:1:0.01])
sigma = 0.1
fig, ax = plt.subplots(1, 3, figsize=(10, 4))
ax[0].imshow(x)
ax[0].axis(False)

ax[1].imshow(y)
ax[1].axis(False)

ax[2].imshow(np.exp(-(x*x+y*y)/2/sigma/sigma))
ax[2].axis(False)
# Out:
# (-0.5, 199.5, 199.5, -0.5)

# %%
x= np.r_[0:2:0.01]
fig, ax = plt.subplots(1,1)
ax.plot(x, np.exp(x))
ax.set_ylim(0, 10)
ax.set_title('exponential function')
# Out:
# Text(0.5, 1.0, 'exponential function')

# %%
plt.title()
# Out:
# (0, 3)

# %%
x, y = np.meshgrid(np.r_[-1:1:0.01], np.r_[-1:1:0.01])
sigma = 0.1
fig, ax = plt.subplots(1, 3, figsize=(10, 4))

ax[0].imshow(x)
ax[0].axis(False)

ax[1].imshow(y, cmap='cubehelix')
ax[1].axis(False)

cx, cy = 0, -0.3 
z = np.exp(-((x-cx)**2+(y-cy)**2)/2/sigma/sigma)
cx, cy = 0.2, 0.3 
z -= np.exp(-((x-cx)**2+(y-cy)**2)/2/sigma/sigma)

ax[2].imshow(z, cmap='Spectral')
ax[2].axis(False)
# Out:
# (-0.5, 199.5, 199.5, -0.5)

# %%
import requests
import os
import imageio

# %%
url = "https://upload.wikimedia.org/wikipedia/commons/d/dc/PLoSBiol4.e126.Fig6fNeuron.jpg"
url = "https://upload.wikimedia.org/wikipedia/commons/thumb/4/40/The_Kiss_-_Gustav_Klimt_-_Google_Cultural_Institute.jpg/765px-The_Kiss_-_Gustav_Klimt_-_Google_Cultural_Institute.jpg"

# %%
local_file = url.split('/')[-1]
local_file
# Out:
# '765px-The_Kiss_-_Gustav_Klimt_-_Google_Cultural_Institute.jpg'

# %%
with open(local_file, 'wb') as f:
    f.write(requests.get(url).content)

# %%
img = imageio.imread(local_file)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 10))
ax.imshow(img)
ax.axis(False)
# Out:
# (-0.5, 764.5, 767.5, -0.5)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 10))
ax.imshow(img.mean(axis=-1), cmap='inferno')
ax.axis(False)
# Out:
# (-0.5, 764.5, 767.5, -0.5)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 10))
ax.imshow(img.mean(axis=-1), cmap='inferno')
ax.axis(False)
# Out:
# (768, 765)

# %%
fig, ax = plt.subplots(1, 3, figsize=(18, 10))
ax[0].imshow(img[:,:,0], cmap='gray')
ax[0].axis(False)
ax[1].imshow(img[:,:,1], cmap='gray')
ax[1].axis(False)
ax[2].imshow(img[:,:,2], cmap='gray')
ax[2].axis(False)
# Out:
# (-0.5, 764.5, 767.5, -0.5)

# %%
ig, ax = plt.subplots(1, 3, figsize=(18, 10))
ax[0].imshow(img[100:300,200:300,:], cmap='gray')
ax[0].axis(False)
ax[1].imshow(img[300:700:4,300:400:4,2], cmap='gray')
ax[1].axis(False)
ax[2].imshow(img[200:700,500:700,:], cmap='gray')
ax[2].axis(False)
# Out:
# (-0.5, 199.5, 499.5, -0.5)

# %%
fix, ax = plt.subplots(1, 3, figsize=(10, 4))
ax[0].hist(img[:,:,0].flatten(), bins=256);
ax[1].hist(img[:,:,1].flatten(), bins=256);
ax[2].hist(img[:,:,2].flatten(), bins=256);

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
plt.scatter(img[::5,::5,0:2].mean(axis=-1).flatten(), img[::5,::5, 2].flatten(), s=1) 
ax.set_xlabel('yellow')
ax.set_ylabel('blue')
# Out:
# Text(0, 0.5, 'blue')
